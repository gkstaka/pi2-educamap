# %%
import pandas as pd 

df = pd.read_csv('./data/listaEscolasDFInep.csv')

df.head(2)
# Out:
#                             Restrição de Atendimento  \
# 0  ESCOLA ATENDE EXCLUSIVAMENTE ALUNOS COM DEFICI...
# 1         ESCOLA EXCLUSIVA DE ATIVIDADE COMPLEMENTAR
#
#                                        Escola  Código INEP  UF Município  \
# 0  ASSOC DE PAIS E AMIGOS DOS EXCEP - APAE-DF     53000030  DF  Brasília
# 1                          CEE 02 DE BRASILIA     53000200  DF  Brasília
#
#   Localização                            Localidade Diferenciada  \
# 0      Urbana  A escola não está em área de localização difer...
# 1      Urbana  A escola não está em área de localização difer...
#
#   Categoria Administrativa                                           Endereço  \
# 0                  Privada  QUADRA SGAN 711/911, ASA NORTE. 70790-115 Bras...
# 1                  Pública  QUADRA SGAS 612 MODULO D, ASA SUL. ASA SUL. 70...
#
#          Telefone Dependência Administrativa Categoria Escola Privada  \
# 0  (61) 993389242                    Privada             Filantrópica
# ...
