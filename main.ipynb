# %%
import pandas as pd 

# Dados de escolas do INEP
df = pd.read_csv('./data/listaEscolasDFInep.csv')

df.head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21052\3423960107.py in ?()
#       2
#       3 # Dados de escolas do INEP
#       4 df = pd.read_csv('./data/listaEscolasDFInep.csv')
#       5
# ----> 6 df.head(15).style.background_gradient(cmap='YlGnBu', subset=['QT_MAT_BAS'])\
#       7                  .format(precision=0)
#
# c:\Users\Pichau\Faculdade\IESB\pi2-educamap\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# c:\Users\Pichau\Faculdade\IESB\pi2-educamap\venv\Lib\site-packages\pandas\core\frame.py in ?(self)
#    1426         """
# ...
